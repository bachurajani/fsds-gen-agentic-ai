# %% [markdown]
# # PYTHON PROGRAM LANGUAGE

# %% [markdown]
# ![image.png](attachment:60319f5d-585d-41ce-8355-9024b3b82ab5.png)

# %% [raw]
# We will learn Python from Basics to advance

# %%
'welcome to python programming language'
# Out:
# 'welcome to python programming language'

# %%
import sys

# %%
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

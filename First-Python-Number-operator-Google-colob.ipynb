# %%
3+5
# Out:
# 8

# %%
8-3
# Out:
# 5

# %%
8_3
# Out:
# 83

# %%
_
# Out:
# 83

# %%
_ + 10
# Out:
# 93

# %%
_ -3
# Out:
# 90

# %%
_ / 10  #Float division
# Out:
# 9.0

# %%
90 // 10 #int division
# Out:
# 9

# %%
_ *9
# Out:
# 81

# %%
4/(5-10)*3 #brack,div,mul,add,sub
# Out:
# -2.4000000000000004

# %%
4+(5-10)*5 #bodmas
# Out:
# -21
